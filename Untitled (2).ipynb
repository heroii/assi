# %%
#q1
#There are two types of pdf 
#1) probability density function is the probablity distribution function for continuous random variable,these pdf depends on few parameters
# for ex normal distribution depend upon mean and std deviation
#2) probablity mass function is the probablity distribution function for discrete random variable,for example the binomial distribution.

# %%
import numpy as np
import pandas as pd
import seaborn as sns

ch=np.random.normal(loc=0,scale=1,size=1000)

# %%
sns.kdeplot(ch)
# it is a pdf of the continuous random variable
# Out:
# <AxesSubplot: ylabel='Density'>

# %%
df=np.random.binomial(n=10,p=0.2,size=100)
#it is a pmf

# %%
sns.histplot(df)
# Out:
# <AxesSubplot: ylabel='Count'>

# %%
# 2
#cummalative density function is used to calculate the probability of continuous random variable upto a point.
# P(0<=X) , where X is random variable

# %%
import numpy as np
import seaborn as sns
ch=np.random.normal(loc=0,scale=1,size=1000)

# %%
sns.kdeplot(ch)
# Out:
# <AxesSubplot: ylabel='Density'>

# %%
#for example
#we want to calculate the probablity upto 1, we can find the cummaltive probability by integrating the pdf function upto 1 from 0.

# %%
#q3
#normal distribution can be used as a model for the situation which are most common, such as data of height of individuals.
#parameter are mean and standard deviationw,
# if we increase the mean the peakness will increase, and if if increase the std, the graph will become flatter.

# %%
# importance of normal distribution
# it is the most common pdf , a lot study is made on it hence we know have much information related to it and when we seee it we get comfortable with it
# mean=median=mode
# ClT theorem can applied and inferential statistics can be applied.

# %%
df=pd.read_csv('iris.csv')
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
sns.kdeplot(df['SepalWidthCm'])
# Out:
# <AxesSubplot: xlabel='SepalWidthCm', ylabel='Density'>

# %%
# q5
# bernouli distribution is a discrte case where the outcomes are binary and it used to find the probability of a outcome  of sucess
#Ex tossing a coin single time to map the possiblity of the head
# in binomial the binary event is performed n number of times then it probablity is marked
#ex tossing the coin 5 time to map the possiblity of head

# %%
ef=np.random.normal(loc=50,scale=10,size=1000)

# %%
sns.kdeplot(ef)
# Out:
# <AxesSubplot: ylabel='Density'>

# %%
#if we take prob density to be of 60 to be 0.015
#we can calculate the z score

# %%
Z=(60-50)/10

# %%
Z
# Out:
# 1.0

# %%
#Z value of 1 is 0.843

# %%
# the answer we will get by subtracting 
prob=1-0.843

# %%
prob
# Out:
# 0.15700000000000003

# %%
#q7
fg=np.random.uniform(size=2000)
# in uniform distribution all outcomes are equviprobable

# %%
sns.kdeplot(fg)
# Out:
# <AxesSubplot: ylabel='Density'>

# %%
#q9
# z score helps every normal distribution in converting in standard normal variate, by using the z score we can calculate the probablity

# %%
#z=(xi-mean)/std

# %%
# central limit theorem states that sampling of any distribution with sample size of more than or equal to 30, and plotting the sanmple , the mean of sample will be equal to the population mean,and the graph will be normal distributrion and std will bes/sqrt(n)

# %%
#10
# sampling should be random.sample size should be more than or equal to 30
